-- %%
-- This takes quite a while for a large number of documents (more pages = more time)
-- Recommend running overnight!
CREATE OR REPLACE TABLE shm.contracts.parsed AS 
SELECT
  * EXCEPT(content),
  _metadata,
  ai_parse_document(
    content,
    map(
      'imageOutputPath', '/Volumes/shm/contracts/parsed_images/',
      'descriptionElementTypes', '*'
    )
  ) AS parsed
FROM READ_FILES('/Volumes/shm/contracts/raw/*.{pdf,jpg,jpeg,png,doc,docx,ppt,pptx}', format => 'binaryFile')
